# %%
import pandas as pd
data=pd.read_csv("car_price_dataset.csv")
data
# Out:
#            Brand     Model  Year  Engine_Size Fuel_Type    Transmission  \
# 0            Kia       Rio  2020          4.2    Diesel          Manual
# 1      Chevrolet    Malibu  2012          2.0    Hybrid       Automatic
# 2       Mercedes       GLA  2020          4.2    Diesel       Automatic
# 3           Audi        Q5  2023          2.0  Electric          Manual
# 4     Volkswagen      Golf  2003          2.6    Hybrid  Semi-Automatic
# ...          ...       ...   ...          ...       ...             ...
# 9995         Kia    Optima  2004          3.7    Diesel  Semi-Automatic
# 9996   Chevrolet    Impala  2002          1.4  Electric       Automatic
# 9997         BMW  3 Series  2010          3.0    Petrol       Automatic
# 9998        Ford  Explorer  2002          1.4    Hybrid       Automatic
# 9999  Volkswagen    Tiguan  2001          2.1    Diesel          Manual
#
#       Mileage  Doors  Owner_Count  Price
# 0      289944      3            5   8501
# ...

# %%
cars_2019 = data[data["Year"] == 2019]
most_sold_brand = cars_2019["Brand"].value_counts().idxmax()

print(f"The most sold brand in 2019 is: {most_sold_brand}")
# Out:
# The most sold brand in 2019 is: Honda

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Brand         10000 non-null  object
#  1   Model         10000 non-null  object
#  2   Year          10000 non-null  int64
#  3   Engine_Size   10000 non-null  float64
#  4   Fuel_Type     10000 non-null  object
#  5   Transmission  10000 non-null  object
#  6   Mileage       10000 non-null  int64
#  7   Doors         10000 non-null  int64
#  8   Owner_Count   10000 non-null  int64
#  9   Price         10000 non-null  int64
# dtypes: float64(1), int64(5), object(4)
# memory usage: 781.4+ KB

# %%
data.describe()
# Out:
#                Year   Engine_Size        Mileage         Doors   Owner_Count  \
# count  10000.000000  10000.000000   10000.000000  10000.000000  10000.000000
# mean    2011.543700      3.000560  149239.111800      3.497100      2.991100
# std        6.897699      1.149324   86322.348957      1.110097      1.422682
# min     2000.000000      1.000000      25.000000      2.000000      1.000000
# 25%     2006.000000      2.000000   74649.250000      3.000000      2.000000
# 50%     2012.000000      3.000000  149587.000000      3.000000      3.000000
# 75%     2017.000000      4.000000  223577.500000      4.000000      4.000000
# max     2023.000000      5.000000  299947.000000      5.000000      5.000000
#
#              Price
# count  10000.00000
# mean    8852.96440
# std     3112.59681
# min     2000.00000
# 25%     6646.00000
# 50%     8858.50000
# 75%    11086.50000
# max    18301.00000

# %%
data.value_counts()
# Out:
# Brand       Model     Year  Engine_Size  Fuel_Type  Transmission    Mileage  Doors  Owner_Count  Price
# Audi        A3        2000  1.7          Electric   Semi-Automatic  259907   4      1            2601     1
# Kia         Rio       2017  2.9          Electric   Manual          8920     3      3            13921    1
#                       2016  4.6          Diesel     Semi-Automatic  113169   3      4            11236    1
#                       2017  1.4          Diesel     Semi-Automatic  212576   2      3            6348     1
#                             1.9          Diesel     Semi-Automatic  173224   5      2            7635     1
#                                                                                                          ..
# Ford        Explorer  2021  2.0          Hybrid     Manual          153706   5      1            10325    1
#                             2.3          Electric   Semi-Automatic  248883   2      4            9722     1
# ...

# %%
data.Year.value_counts()
# Out:
# Year
# 2002    462
# 2011    449
# 2023    448
# 2012    437
# 2017    433
# 2010    431
# 2005    431
# 2007    430
# 2015    426
# 2018    425
# 2013    422
# 2019    421
# 2014    417
# 2006    415
# 2020    415
# 2001    406
# 2009    399
# 2022    397
# 2016    395
# 2004    394
# 2000    393
# 2021    391
# 2008    382
# 2003    381
# Name: count, dtype: int64

# %%
# Check unique values for categorical columns
print("Unique values in 'Fuel_Type':", data['Fuel_Type'].unique())
print("Unique values in 'Transmission':", data['Transmission'].unique())
# Out:
# Unique values in 'Fuel_Type': ['Diesel' 'Hybrid' 'Electric' 'Petrol']
# Unique values in 'Transmission': ['Manual' 'Automatic' 'Semi-Automatic']

# %%
# Identify outliers in Mileage and Price using boxplot visualization
import matplotlib.pyplot as plt
import seaborn as sns
# Mileage boxplot
# plt.subplot(2,2,1)
sns.boxplot(data['Mileage'], color='skyblue')
plt.title('Boxplot of Mileage')
plt.show()

# %%
# 1. Pie Chart - Distribution of Fuel Types
fuel_counts = data['Fuel_Type'].value_counts()
plt.pie(fuel_counts, labels=fuel_counts.index, autopct='%1.1f%%', colors=['#ff9999', '#66b3ff', '#99ff99', '#ffcc99'])
plt.title('Distribution of Fuel Types')
# Out:
# Text(0.5, 1.0, 'Distribution of Fuel Types')

# %%
# 3. Violin Plot - Price vs Fuel Type
sns.violinplot(x='Fuel_Type', y='Price', data=data, palette='Set2')
plt.title('Price vs Fuel Type')
# Out:
# C:\Users\Poojitha\AppData\Local\Temp\ipykernel_12952\3371631960.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='Fuel_Type', y='Price', data=data, palette='Set2')
# Text(0.5, 1.0, 'Price vs Fuel Type')

# %%
# 2. Pie Chart - Distribution of Transmission Types
transmission_counts = data['Transmission'].value_counts()
plt.pie(transmission_counts, labels=transmission_counts.index, autopct='%1.1f%%', colors=['#BE398D', '#F5C26B', '#5C62D6'])
plt.title('Distribution of Transmission Types')
# Out:
# Text(0.5, 1.0, 'Distribution of Transmission Types')

# %%
# Price boxplot
sns.boxplot(data['Price'], color='salmon')
plt.title('Boxplot of Price')
plt.show()

# %%
# 4. Violin Plot - Price vs Transmission Type
sns.violinplot(x='Transmission', y='Price', data=data, palette='Set1')
plt.title('Price vs Transmission Type')
# Out:
# C:\Users\Poojitha\AppData\Local\Temp\ipykernel_12952\3819430965.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='Transmission', y='Price', data=data, palette='Set1')
# Text(0.5, 1.0, 'Price vs Transmission Type')

# %%
# 1. Distribution of Car Prices
sns.histplot(data['Price'], bins=30, color='skyblue', kde=True)
plt.title('Distribution of Car Prices')
plt.show()

# %%
# 2. Distribution of Engine Sizes by Fuel Type
sns.boxplot(x='Fuel_Type', y='Engine_Size', data=data, palette='Set2')
plt.title('Engine Sizes by Fuel Type')
# Out:
# C:\Users\Poojitha\AppData\Local\Temp\ipykernel_12952\3330212089.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Fuel_Type', y='Engine_Size', data=data, palette='Set2')
# Text(0.5, 1.0, 'Engine Sizes by Fuel Type')

# %%
# 3. Mileage vs Price Scatter Plot
sns.scatterplot(x='Mileage', y='Price', hue='Fuel_Type', data=data, palette='viridis')
plt.title('Mileage vs Price by Fuel Type')
# Out:
# Text(0.5, 1.0, 'Mileage vs Price by Fuel Type')

# %%
# 4. Count of Transmission Types
sns.countplot(x='Transmission', data=data, palette='pastel')
plt.title('Count of Transmission Types')
# Out:
# C:\Users\Poojitha\AppData\Local\Temp\ipykernel_12952\2114115799.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Transmission', data=data, palette='pastel')
# Text(0.5, 1.0, 'Count of Transmission Types')

# %%
# 5. Price vs Year with Regression Line
sns.regplot(x='Year', y='Price', data=data, color='coral')
plt.title('Price vs Year')
# Out:
# Text(0.5, 1.0, 'Price vs Year')

# %%
# 6. Owner Count Distribution
sns.countplot(x='Owner_Count', data=data, palette='coolwarm')
plt.title('Distribution of Owner Counts')
# Out:
# C:\Users\Poojitha\AppData\Local\Temp\ipykernel_12952\4180208831.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Owner_Count', data=data, palette='coolwarm')
# Text(0.5, 1.0, 'Distribution of Owner Counts')

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
import pandas as pd

# Assuming 'data' is your cleaned dataset
data_encoded = pd.get_dummies(data, drop_first=True)

# Features and target variable
X = data_encoded.drop('Price', axis=1)
y = data_encoded['Price']

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Model training
model = LinearRegression()
model.fit(X_train, y_train)

# Predictions
y_pred = model.predict(X_test)

# Mean Squared Error calculation
mse = mean_squared_error(y_test, y_pred)
print(f"Mean Squared Error (MSE): {mse:.2f}")
# Out:
# Mean Squared Error (MSE): 8132.08

# %%
# Handling outliers using the IQR method
def remove_outliers(df, column):
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    return df[(df[column] >= lower_bound) & (df[column] <= upper_bound)]

# Remove outliers from Mileage and Price
data = remove_outliers(data, 'Mileage')
data = remove_outliers(data, 'Price')

# Verify the shape after outlier removal
data.shape
# Out:
# (9994, 10)
